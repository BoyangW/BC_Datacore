# %% [markdown]
# ## FV and Fat Outcomes Extraction
# #### This notebook extracts 212 participants' self-reported fruit/vegetable credits and fat from raw dataset with daily level granularity
# #### The inputs and outputs are in csv format

# %%
import pandas as pd
import numpy as np
import pandasql as ps
import time 
import datetime 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#import tables
df_food = pd.read_csv('Raw Data/food_upload.csv') 
df_food_item = pd.read_csv('Raw Data/food_foods_fv.csv')
df_food_serving = pd.read_csv('Raw Data/food_servings.csv')
df_user = pd.read_csv('Raw Data/users.csv') 
df_recipe = pd.read_csv('Raw Data/recipe_upload.csv')

# %%
df_food.head(5)
# Out:
#             event_time serving_id  food_id serving_time  amount  \
# 0  2012-07-18 09:31:14     202550  1092354    Breakfast    0.75
# 1  2012-07-18 14:53:38      55917  1083753    Breakfast    1.00
# 2  2012-07-18 14:55:32     190733  1067522    Breakfast    1.00
# 3  2012-07-18 14:57:15      19474  1055153    Breakfast    1.00
# 4  2012-07-19 13:08:00      40275  1052381    Breakfast    0.50
#
#            time_upload  user_id                         aid  status  \
# 0  2012-07-18 09:33:10  1000001  014312012618A000002C80E683     NaN
# 1  2012-07-18 14:56:44        1  038532012618A000002C813830     NaN
# 2  2012-07-18 14:56:44        1  132552012618A000002C813830     NaN
# 3  2012-07-18 15:33:44        1  215572012618A000002C813830     NaN
# 4  2012-07-19 15:58:14        3   05972012619A000002C816464     NaN
#
#    update_time  credit  favorites
# 0          NaN    0.39          0
# 1          NaN    0.00          0
# 2          NaN    1.00          0
# 3          NaN    0.00          0
# 4          NaN    0.00          0

# %%
df_food_item.head(5)
# Out:
#    food_id  category_id                    name  is_fv  fv_excl_crit  \
# 0  1001004         8148              Blue, bleu    NaN           NaN
# 1  1001006         8148                    Brie    NaN           NaN
# 2  1001009         8148                 Cheddar    NaN           NaN
# 3  1001011         8148                   Colby    NaN           NaN
# 4  1001026         8148  Mozzarella, whole milk    NaN           NaN
#
#   is_fv_auto  isfv_tagger1  why1  isfv_tagger2  why2  ...  calories  protein  \
# 0      False           NaN   NaN           NaN   NaN  ...     353.0    21.40
# 1      False           NaN   NaN           NaN   NaN  ...     334.0    20.75
# 2      False           NaN   NaN           NaN   NaN  ...     403.0    24.90
# 3      False           NaN   NaN           NaN   NaN  ...     394.0    23.76
# 4      False           NaN   NaN           NaN   NaN  ...     300.0    22.17
#
#    total_fat  total_carbohydrate  sugars  fiber calcium  sodium  \
# 0      28.74                2.34    0.50    0.0   528.0  1395.0
# 1      27.68                0.45    0.45    0.0   184.0   629.0
# 2      33.14                1.28    0.52    0.0   721.0   621.0
# 3      32.11                2.57    0.52    0.0   685.0   604.0
# 4      22.35                2.19    1.03    0.0   505.0   627.0
#
#   saturated_fatty_acids cholesterol
# 0                18.669        75.0
# 1                17.410       100.0
# 2                21.092       105.0
# 3                20.218        95.0
# 4                13.152        79.0
#
# [5 rows x 30 columns]

# %%
df_food_serving.head(5)
# Out:
#    serving_id  food_id                                          name    size  \
# 0      115152  1112899            serving, 1/5 broccoflower (3.5 oz)    99.0
# 1      191727  1063605  melon, 15" long x 7-1/2" dia (9 lbs 15.4 oz)  4518.0
# 2      200244  1173830                              bag (4 lbs 8 oz)  2041.0
# 3      200217  1173827                              bag (4 lbs 8 oz)  2041.0
# 4      200235  1122058                              bag (3 lbs 8 oz)  1588.0
#
#    fv_credit  fv_cup           fv_type
# 0       3.04    1.52  S = Standard x 2
# 1      59.00   29.50  S = Standard x 2
# 2      58.32   29.16  S = Standard x 2
# 3      45.36   22.68  S = Standard x 2
# 4      37.36   18.68  S = Standard x 2

# %%
df_food_serving[df_food_serving['food_id']==1122058]
# Out:
#       serving_id  food_id              name    size  fv_credit  fv_cup  \
# 4         200235  1122058  bag (3 lbs 8 oz)  1588.0      37.36   18.68
# 345       124520  1122058       box (10 oz)   284.0       6.68    3.34
# 1770      103368  1122058        cup (3 oz)    85.0       2.00    1.00
#
#                fv_type
# 4     S = Standard x 2
# 345   S = Standard x 2
# 1770  S = Standard x 2

# %%
df_recipe.head(5)
# Out:
#                         itemid        creation_time  food_id  item_amount  \
# 0   154082013115A000002CC5E5C1  2013-02-15 12:08:40  1063879         0.75
# 1   154982013115A000002CC5E5C1  2013-02-15 12:08:49  1062683         0.75
# 2   154082013115A000002CC5E5C1  2013-02-15 12:08:40  1063879         0.75
# 3   154982013115A000002CC5E5C1  2013-02-15 12:08:49  1062683         0.75
# 4  4723232013115A000002C81488E  2013-02-15 17:23:23  1109969         1.00
#
#    serving_id recipe_name  user_id                    recipe_id  \
# 0      218681       apple  1000001  1949272013115A000002CC5E5C1
# 1      110732       apple  1000001  1949272013115A000002CC5E5C1
# 2      218681       apple  1000001  2147292013115A000002CC5E5C1
# 3      110732       apple  1000001  2147292013115A000002CC5E5C1
# 4       88248   Breakfast      244  4756242013115A000002C81488E
#
#            server_time  creditrecipe  servamount     id
# 0  2013-02-15 12:47:07          2.19           2  25331
# 1  2013-02-15 12:47:07          0.15           2  25332
# 2  2013-02-15 12:47:07          2.19           2  25333
# 3  2013-02-15 12:47:07          0.15           2  25334
# 4  2013-02-15 18:00:48          0.00           1  25335

# %% [markdown]
# ### Extract User (intervention + follow-up)

# %%
#all participants
id_list = []
for i in range(df_user.shape[0]):
    #extract users' name starting with 'mbc2'
    if (df_user['username'][i][0:4] == 'mbc2'):
        id_list.append(df_user['user_id'][i])
id_list.sort()

print('There are', len(id_list), 'participants in intervention/follow-up period')
# Out:
# There are 212 participants in intervention/follow-up period

# %% [markdown]
# ### Extract Recipe

# %%
# selecting rows for participants only
df_recipe = df_recipe[df_recipe['user_id'].isin(id_list)]
df_recipe = df_recipe.sort_values(by=['creation_time'])
df_recipe.head(5)
# Out:
#                           itemid        creation_time  food_id  item_amount  \
# 146    16432013122A000002C8119D3  2013-02-22 12:43:06  1068093          2.0
# 147    13442013122A000002C8119D3  2013-02-22 12:44:03  1179404          3.0
# 148   145442013122A000002C8119D3  2013-02-22 12:44:45  1001009          1.0
# 149   139452013122A000002C8119D3  2013-02-22 12:45:39  1111083          1.0
# 24   1081432013126A000002C81309B  2013-02-26 12:43:01  1159186          1.0
#
#      serving_id        recipe_name  user_id                    recipe_id  \
# 146      190899    Turkey Sandwich      291  3021823201333A000002C8119D3
# 147      210370    Turkey Sandwich      291  3021823201333A000002C8119D3
# 148      191079    Turkey Sandwich      291  3021823201333A000002C8119D3
# 149      172296    Turkey Sandwich      291  3021823201333A000002C8119D3
# 24       175721  Whole Foods Salad      288           12421412013127none
#
#              server_time  creditrecipe  servamount     id
# 146  2013-04-03 11:24:09           0.0           1  25477
# 147  2013-04-03 11:24:09           0.0           1  25478
# 148  2013-04-03 11:24:09           0.0           1  25479
# 149  2013-04-03 11:24:09           0.0           1  25480
# 24   2013-02-27 19:29:49           3.0           1  25355

# %%
#columns of interest
col = ['user_id', 'creation_time', 'food_id', 'serving_id', 'item_amount', 'recipe_name', 'creditrecipe', 'servamount']
df_recipe = df_recipe[col]
df_recipe.head(5)
# Out:
#      user_id        creation_time  food_id  serving_id  item_amount  \
# 146      291  2013-02-22 12:43:06  1068093      190899          2.0
# 147      291  2013-02-22 12:44:03  1179404      210370          3.0
# 148      291  2013-02-22 12:44:45  1001009      191079          1.0
# 149      291  2013-02-22 12:45:39  1111083      172296          1.0
# 24       288  2013-02-26 12:43:01  1159186      175721          1.0
#
#            recipe_name  creditrecipe  servamount
# 146    Turkey Sandwich           0.0           1
# 147    Turkey Sandwich           0.0           1
# 148    Turkey Sandwich           0.0           1
# 149    Turkey Sandwich           0.0           1
# 24   Whole Foods Salad           3.0           1

# %%
#Merge upload and item (sql)
df_test = ps.sqldf("SELECT d1.food_id as food_id, d1.creditrecipe, d1.serving_id, d1.creation_time as upload_time, d1.user_id, d1.item_amount as amount, d2.name, d2.base, d2.calories, d2.protein, d2.total_fat, d2.total_carbohydrate, d2.sugars, d2.fiber, d2.calcium, d2.sodium, d2.saturated_fatty_acids, d2.cholesterol FROM df_recipe as d1 LEFT JOIN df_food_item as d2 ON d1.food_id = d2.food_id")

# %%
df_test.head(6)
# Out:
#    food_id  creditrecipe  serving_id          upload_time  user_id  amount  \
# 0  1068093           0.0      190899  2013-02-22 12:43:06      291     2.0
# 1  1179404           0.0      210370  2013-02-22 12:44:03      291     3.0
# 2  1001009           0.0      191079  2013-02-22 12:44:45      291     1.0
# 3  1111083           0.0      172296  2013-02-22 12:45:39      291     1.0
# 4  1159186           3.0      175721  2013-02-26 12:43:01      288     1.0
# 5  1159186           3.0      175721  2013-02-26 12:43:01      288     1.0
#
#                                                 name   base  calories  \
# 0                                        White Bread  100.0     266.0
# 1  Deep Fried, Turkey Breast, Extra Thin Sliced, ...   56.0      60.0
# 2                                            Cheddar  100.0     403.0
# 3                            Mustard, Classic Yellow    5.0       0.0
# 4           Tender Lettuce Mixes, Fancy Field Greens   85.0      20.0
# 5           Tender Lettuce Mixes, Fancy Field Greens   85.0      20.0
#
#    protein  total_fat  total_carbohydrate  sugars  fiber  calcium  sodium  \
# 0     7.64       3.29               50.61    4.31    2.4    151.0   681.0
# 1    10.00       1.50                3.00    1.00    0.0      0.0   550.0
# 2    24.90      33.14                1.28    0.52    0.0    721.0   621.0
# 3     0.00       0.00                1.00    0.50    0.0      0.0    55.0
# 4     1.00       0.00                3.00    1.00    2.0     20.0    15.0
# 5     1.00       0.00                3.00    1.00    2.0     20.0    15.0
#
#    saturated_fatty_acids  cholesterol
# 0                  0.717          0.0
# 1                  0.000         25.0
# 2                 21.092        105.0
# 3                  0.000          0.0
# 4                  0.000          0.0
# 5                  0.000          0.0

# %%
df_test_clean = df_test.drop_duplicates()
df_test_clean["base"] = df_test_clean["base"].fillna(1)
df_test_clean.head(5)
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    food_id  creditrecipe  serving_id          upload_time  user_id  amount  \
# 0  1068093           0.0      190899  2013-02-22 12:43:06      291     2.0
# 1  1179404           0.0      210370  2013-02-22 12:44:03      291     3.0
# 2  1001009           0.0      191079  2013-02-22 12:44:45      291     1.0
# 3  1111083           0.0      172296  2013-02-22 12:45:39      291     1.0
# 4  1159186           3.0      175721  2013-02-26 12:43:01      288     1.0
#
#                                                 name   base  calories  \
# 0                                        White Bread  100.0     266.0
# 1  Deep Fried, Turkey Breast, Extra Thin Sliced, ...   56.0      60.0
# 2                                            Cheddar  100.0     403.0
# 3                            Mustard, Classic Yellow    5.0       0.0
# 4           Tender Lettuce Mixes, Fancy Field Greens   85.0      20.0
#
#    protein  total_fat  total_carbohydrate  sugars  fiber  calcium  sodium  \
# 0     7.64       3.29               50.61    4.31    2.4    151.0   681.0
# 1    10.00       1.50                3.00    1.00    0.0      0.0   550.0
# 2    24.90      33.14                1.28    0.52    0.0    721.0   621.0
# 3     0.00       0.00                1.00    0.50    0.0      0.0    55.0
# 4     1.00       0.00                3.00    1.00    2.0     20.0    15.0
#
#    saturated_fatty_acids  cholesterol
# 0                  0.717          0.0
# 1                  0.000         25.0
# 2                 21.092        105.0
# 3                  0.000          0.0
# 4                  0.000          0.0

# %%
#fill all null nutrition facts with 0
nutrition_List = ['calories', 'protein','total_fat', 'total_carbohydrate', 'sugars', 'fiber', 'calcium','sodium', 'saturated_fatty_acids', 'cholesterol']
for nutrition_item in nutrition_List:
    df_test_clean[nutrition_item] = df_test_clean[nutrition_item].fillna(0)
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
#Merge upload and serving (sql)
df_test2 = ps.sqldf("SELECT d1.food_id as food_id, d1.creditrecipe, d1.serving_id as serving_id, d2.size, d2.fv_credit, d1.upload_time, d1.user_id, d1.amount, d1.name, d1.base, d1.calories, d1.protein, d1.total_fat, d1.total_carbohydrate, d1.sugars, d1.fiber, d1.calcium, d1.sodium, d1.saturated_fatty_acids, d1.cholesterol FROM df_test_clean as d1 INNER JOIN df_food_serving as d2 ON d1.Food_ID = d2.food_id and d1.serving_id = d2.serving_id")
df_test2.head(5)
# Out:
#    food_id  creditrecipe  serving_id  size  fv_credit          upload_time  \
# 0  1068093           0.0      190899  30.0        0.0  2013-02-22 12:43:06
# 1  1179404           0.0      210370   8.0        0.0  2013-02-22 12:44:03
# 2  1001009           0.0      191079  28.0        0.0  2013-02-22 12:44:45
# 3  1111083           0.0      172296   5.0        0.0  2013-02-22 12:45:39
# 4  1159186           3.0      175721  85.0        3.0  2013-02-26 12:43:01
#
#    user_id  amount                                               name   base  \
# 0      291     2.0                                        White Bread  100.0
# 1      291     3.0  Deep Fried, Turkey Breast, Extra Thin Sliced, ...   56.0
# 2      291     1.0                                            Cheddar  100.0
# 3      291     1.0                            Mustard, Classic Yellow    5.0
# 4      288     1.0           Tender Lettuce Mixes, Fancy Field Greens   85.0
#
#    calories  protein  total_fat  total_carbohydrate  sugars  fiber  calcium  \
# 0     266.0     7.64       3.29               50.61    4.31    2.4    151.0
# 1      60.0    10.00       1.50                3.00    1.00    0.0      0.0
# 2     403.0    24.90      33.14                1.28    0.52    0.0    721.0
# 3       0.0     0.00       0.00                1.00    0.50    0.0      0.0
# 4      20.0     1.00       0.00                3.00    1.00    2.0     20.0
#
#    sodium  saturated_fatty_acids  cholesterol
# 0   681.0                  0.717          0.0
# 1   550.0                  0.000         25.0
# 2   621.0                 21.092        105.0
# 3    55.0                  0.000          0.0
# 4    15.0                  0.000          0.0

# %%
#calculation
nutrition_List = ['calories',
 'protein',
 'total_fat',
 'total_carbohydrate',
 'sugars',
 'fiber',
 'calcium',
 'sodium',
 'saturated_fatty_acids',
 'cholesterol']

included_List = ['user_id', 'food_id','serving_id','upload_time','name', 'amount','base','size','creditrecipe','fv_credit']
included_List = included_List + nutrition_List
df_test2 = df_test2[included_List]

# %%
#Applying to entire dataframe
#After Calculation
import warnings
warnings.filterwarnings("ignore")
df_final = df_test2
for nutrition_item in nutrition_List:
    for i in range(df_final.shape[0]):
        df_final[nutrition_item][i] = df_final['size'][i] / df_final['base'][i] * df_final['amount'][i] * df_final[nutrition_item][i]

# %%
#calculate result fv credit (multiply by amount)
for i in range(df_final.shape[0]):
    df_final['fv_credit'][i] = df_final['fv_credit'][i] * df_final['amount'][i]

# %%
df_final.head(5)
# Out:
#    user_id  food_id  serving_id          upload_time  \
# 0      291  1068093      190899  2013-02-22 12:43:06
# 1      291  1179404      210370  2013-02-22 12:44:03
# 2      291  1001009      191079  2013-02-22 12:44:45
# 3      291  1111083      172296  2013-02-22 12:45:39
# 4      288  1159186      175721  2013-02-26 12:43:01
#
#                                                 name  amount   base  size  \
# 0                                        White Bread     2.0  100.0  30.0
# 1  Deep Fried, Turkey Breast, Extra Thin Sliced, ...     3.0   56.0   8.0
# 2                                            Cheddar     1.0  100.0  28.0
# 3                            Mustard, Classic Yellow     1.0    5.0   5.0
# 4           Tender Lettuce Mixes, Fancy Field Greens     1.0   85.0  85.0
#
#    creditrecipe  fv_credit    calories   protein  total_fat  \
# 0           0.0        0.0  159.600000  4.584000   1.974000
# 1           0.0        0.0   25.714286  4.285714   0.642857
# 2           0.0        0.0  112.840000  6.972000   9.279200
# 3           0.0        0.0    0.000000  0.000000   0.000000
# 4           3.0        3.0   20.000000  1.000000   0.000000
#
#    total_carbohydrate    sugars  fiber  calcium      sodium  \
# 0           30.366000  2.586000   1.44    90.60  408.600000
# 1            1.285714  0.428571   0.00     0.00  235.714286
# 2            0.358400  0.145600   0.00   201.88  173.880000
# 3            1.000000  0.500000   0.00     0.00   55.000000
# 4            3.000000  1.000000   2.00    20.00   15.000000
#
#    saturated_fatty_acids  cholesterol
# 0                0.43020     0.000000
# 1                0.00000    10.714286
# 2                5.90576    29.400000
# 3                0.00000     0.000000
# 4                0.00000     0.000000

# %%
df_recipe_final = df_final
df_recipe_final.to_csv('Result/Food/recipe.csv', index=False)

# %%
#get user level
df_recipe_final['upload_time'] = df_recipe_final['upload_time'].astype('string').str[:10]
df_recipe_final.head(3)
# Out:
#    user_id  food_id  serving_id upload_time  \
# 0      291  1068093      190899  2013-02-22
# 1      291  1179404      210370  2013-02-22
# 2      291  1001009      191079  2013-02-22
#
#                                                 name  amount   base  size  \
# 0                                        White Bread     2.0  100.0  30.0
# 1  Deep Fried, Turkey Breast, Extra Thin Sliced, ...     3.0   56.0   8.0
# 2                                            Cheddar     1.0  100.0  28.0
#
#    creditrecipe  fv_credit    calories   protein  total_fat  \
# 0           0.0        0.0  159.600000  4.584000   1.974000
# 1           0.0        0.0   25.714286  4.285714   0.642857
# 2           0.0        0.0  112.840000  6.972000   9.279200
#
#    total_carbohydrate    sugars  fiber  calcium      sodium  \
# 0           30.366000  2.586000   1.44    90.60  408.600000
# 1            1.285714  0.428571   0.00     0.00  235.714286
# 2            0.358400  0.145600   0.00   201.88  173.880000
#
#    saturated_fatty_acids  cholesterol
# 0                0.43020     0.000000
# 1                0.00000    10.714286
# 2                5.90576    29.400000

# %%
#aggregate day-level nutrients (sum)
df_recipe_user = ps.sqldf("SELECT user_id, upload_time as upload_time, sum(calories) as calories, sum(protein) as protein, sum(total_fat) as total_fat, sum(total_carbohydrate) as total_carbohydrate, sum(sugars) as sugars, sum(fiber) as fiber, sum(calcium) as calciumm, sum(sodium) as sodium, sum(saturated_fatty_acids) as saturated_fatty_acids, sum(cholesterol) as cholesterol, sum(fv_credit) as fv_credit FROM df_recipe_final group by user_id, upload_time")

# %%
df_recipe_user.head(5)
# Out:
#    user_id upload_time     calories    protein  total_fat  total_carbohydrate  \
# 0      288  2013-02-26   357.370000  16.183150  16.471550           38.616950
# 1      288  2013-03-05   385.472000  31.866570  18.955470           24.076600
# 2      291  2013-02-22   298.154286  15.841714  11.896057           33.010114
# 3      291  2013-03-03  1428.000000  90.000000  56.000000          145.000000
# 4      291  2013-03-11   759.335000  26.275750  64.114875           32.297125
#
#       sugars     fiber   calciumm       sodium  saturated_fatty_acids  \
# 0  18.739800   8.06925   308.0575   251.597500               6.780085
# 1  12.695900   7.01220   352.2075   630.489780               8.391765
# 2   3.660171   1.44000   292.4800   873.194286               6.335960
# 3  17.000000   6.50000  1600.0000  2740.000000              28.000000
# 4   2.500000  10.24750   341.9250   259.830000              13.338722
#
#    cholesterol  fv_credit
# 0    29.662500      6.590
# 1    70.912500      5.055
# 2    40.114286      0.000
# 3   150.000000      3.400
# 4    31.250000      2.200

# %%
df_recipe_user.to_csv('Result/Food/recipe_userLevel.csv', index=False)

# %% [markdown]
# ### Regular food

# %%
# selecting rows for participants only
df_food_new = df_food[df_food['user_id'].isin(id_list)]
df_food_new = df_food_new.sort_values(by=['time_upload'])

# %%
print('Total number of daily food entries:', df_food.shape[0])
print('Total number of daily food entries for', len(id_list), 'participants only:', df_food_new.shape[0])
# Out:
# Total number of daily food entries: 57738
# Total number of daily food entries for 212 participants only: 37270

# %%
#sanity check (sql)
ps.sqldf("SELECT count(distinct user_id) as Total_Number_User FROM df_food")
# Out:
#    Total_Number_User
# 0                463

# %%
#sanity check (sql)
ps.sqldf("SELECT count(distinct user_id) as Total_Number_Record FROM df_food_new")
# Out:
#    Total_Number_Record
# 0                  212

# %%
#Missing Users
exsiting_user = list(df_food_new['user_id'])
print('User record not found in food upload:', np.setdiff1d(id_list,exsiting_user))
# Out:
# User record not found in food upload: []

# %% [markdown]
# ## Merging food_upload / food_foods_fv / food_servings

# %% [markdown]
# #### Merge food_upload + food_foods_fv

# %%
#Merge upload and item (sql)
df_test = ps.sqldf("SELECT d1.food_id as Food_ID, d2.food_id as Food_ID2, d1.credit, d1.serving_id, d1.time_upload, d1.user_id, d1.serving_time, d1.amount, d2.name, d2.base, d2.calories, d2.protein, d2.total_fat, d2.total_carbohydrate, d2.sugars, d2.fiber, d2.calcium, d2.sodium, d2.saturated_fatty_acids, d2.cholesterol FROM df_food_new as d1 LEFT JOIN df_food_item as d2 ON d1.food_id = d2.food_id")

# %%
#new columns
df_test.columns
# Out:
# Index(['Food_ID', 'Food_ID2', 'credit', 'serving_id', 'time_upload', 'user_id',
#        'serving_time', 'amount', 'name', 'base', 'calories', 'protein',
#        'total_fat', 'total_carbohydrate', 'sugars', 'fiber', 'calcium',
#        'sodium', 'saturated_fatty_acids', 'cholesterol'],
#       dtype='object')

# %%
df_test.shape
# Out:
# (37270, 20)

# %% [markdown]
# 279358 matches from food_upload and merged dataframe (sanity check)

# %%
#fill null fv base values with 1 (avoid zero dividing error)
df_test["base"] = df_test["base"].fillna(1)

# %%
list(df_test)
# Out:
# ['Food_ID',
#  'Food_ID2',
#  'credit',
#  'serving_id',
#  'time_upload',
#  'user_id',
#  'serving_time',
#  'amount',
#  'name',
#  'base',
#  'calories',
#  'protein',
#  'total_fat',
#  'total_carbohydrate',
#  'sugars',
#  'fiber',
#  'calcium',
#  'sodium',
#  'saturated_fatty_acids',
#  'cholesterol']

# %%
#fill all null nutrition facts with 0
nutrition_List = ['calories', 'protein','total_fat', 'total_carbohydrate', 'sugars', 'fiber', 'calcium','sodium', 'saturated_fatty_acids', 'cholesterol']
for nutrition_item in nutrition_List:
    df_test[nutrition_item] = df_test[nutrition_item].fillna(0)

# %% [markdown]
# #### Merge food_upload + food_foods_fv + food_servings

# %%
#Merge upload and item (sql)
df_test2 = ps.sqldf("SELECT d1.Food_ID as Food_ID, d1.Food_ID2 as Food_ID2, d2.food_id as Food_ID3, d1.credit, d1.serving_id as Serving_ID1, d2.serving_id as Serving_ID2, d2.size, d2.fv_credit, d1.time_upload, d1.user_id, d1.serving_time, d1.amount, d1.name, d1.base, d1.calories, d1.protein, d1.total_fat, d1.total_carbohydrate, d1.sugars, d1.fiber, d1.calcium, d1.sodium, d1.saturated_fatty_acids, d1.cholesterol FROM df_test as d1 INNER JOIN df_food_serving as d2 ON d1.Food_ID = d2.food_id and d1.serving_id = d2.serving_id")

# %%
df_test2.head(5)
# Out:
#    Food_ID   Food_ID2  Food_ID3  credit Serving_ID1  Serving_ID2   size  \
# 0  1083753  1083753.0   1083753     0.0       55917        55917  164.0
# 1  1067522  1067522.0   1067522     1.0      190733       190733  257.0
# 2  1055153  1055153.0   1055153     0.0       19474        19474   56.0
# 3  1101026  1101026.0   1101026     0.0       77345        77345  198.0
# 4  1055117  1055117.0   1055117     0.0       31270        31270  117.0
#
#    fv_credit          time_upload  user_id  ... calories  protein total_fat  \
# 0        0.0  2012-07-18 14:56:44        1  ...    420.0     15.0      18.0
# 1        1.0  2012-07-18 14:56:44        1  ...     45.0      0.7       0.2
# 2        0.0  2012-07-18 15:33:44        1  ...    150.0      1.0       9.0
# 3        0.0  2012-07-19 16:43:30        1  ...    510.0     29.0      26.0
# 4        0.0  2012-07-19 16:43:30        1  ...    500.0      6.0      25.0
#
#    total_carbohydrate  sugars  fiber  calcium  sodium  saturated_fatty_acids  \
# 0                48.0    15.0    2.0    200.0  1110.0                  8.000
# 1                10.4     8.4    0.2     11.0     1.0                  0.024
# 2                15.0     0.0    2.0      0.0   310.0                  1.500
# 3                40.0     9.0    3.0    300.0  1190.0                 12.000
# 4                63.0     0.0    6.0     20.0   350.0                  3.500
#
#    cholesterol
# 0        240.0
# 1          0.0
# 2          0.0
# 3         90.0
# 4          0.0
#
# [5 rows x 24 columns]

# %%
print('About', df_test.shape[0] - df_test2.shape[0], 'number of food uploads could not be found with both food item and serving matched')
# Out:
# About 143 number of food uploads could not be found with both food item and serving matched

# %%
df_test2.columns
# Out:
# Index(['Food_ID', 'Food_ID2', 'Food_ID3', 'credit', 'Serving_ID1',
#        'Serving_ID2', 'size', 'fv_credit', 'time_upload', 'user_id',
#        'serving_time', 'amount', 'name', 'base', 'calories', 'protein',
#        'total_fat', 'total_carbohydrate', 'sugars', 'fiber', 'calcium',
#        'sodium', 'saturated_fatty_acids', 'cholesterol'],
#       dtype='object')

# %% [markdown]
# <b>Calculation Part</b>

# %%
nutrition_List = ['calories',
 'protein',
 'total_fat',
 'total_carbohydrate',
 'sugars',
 'fiber',
 'calcium',
 'sodium',
 'saturated_fatty_acids',
 'cholesterol']

# %%
included_List = ['user_id', 'Food_ID','Serving_ID1','time_upload','serving_time','amount','base','size','credit','fv_credit']
included_List = included_List + nutrition_List
included_List
# Out:
# ['user_id',
#  'Food_ID',
#  'Serving_ID1',
#  'time_upload',
#  'serving_time',
#  'amount',
#  'base',
#  'size',
#  'credit',
#  'fv_credit',
#  'calories',
#  'protein',
#  'total_fat',
#  'total_carbohydrate',
#  'sugars',
#  'fiber',
#  'calcium',
#  'sodium',
#  'saturated_fatty_acids',
#  'cholesterol']

# %%
#sample test
df_test2 = df_test2[included_List]
df_test2.columns
# Out:
# Index(['user_id', 'Food_ID', 'Serving_ID1', 'time_upload', 'serving_time',
#        'amount', 'base', 'size', 'credit', 'fv_credit', 'calories', 'protein',
#        'total_fat', 'total_carbohydrate', 'sugars', 'fiber', 'calcium',
#        'sodium', 'saturated_fatty_acids', 'cholesterol'],
#       dtype='object')

# %% [markdown]
# <b>Formula: (food_servings.size / food_foods_fv.base) * food_upload.amount * (nutrition metric)</b>

# %%
#Applying to entire dataframe
#After Calculation
import warnings
warnings.filterwarnings("ignore")
df_final = df_test2
for nutrition_item in nutrition_List:
    for i in range(df_final.shape[0]):
        df_final[nutrition_item][i] = df_final['size'][i] / df_final['base'][i] * df_final['amount'][i] * df_final[nutrition_item][i]

# %%
#calculate result fv credit (multiply by amount)
for i in range(df_final.shape[0]):
    df_final['fv_credit'][i] = df_final['fv_credit'][i] * df_final['amount'][i]

# %%
df_final.head(5)
# Out:
#    user_id  Food_ID Serving_ID1          time_upload serving_time  amount  \
# 0        1  1083753       55917  2012-07-18 14:56:44    Breakfast     1.0
# 1        1  1067522      190733  2012-07-18 14:56:44    Breakfast     1.0
# 2        1  1055153       19474  2012-07-18 15:33:44    Breakfast     1.0
# 3        1  1101026       77345  2012-07-19 16:43:30        Lunch     1.0
# 4        1  1055117       31270  2012-07-19 16:43:30        Lunch     1.0
#
#     base   size  credit  fv_credit    calories    protein  total_fat  \
# 0  164.0  164.0     0.0        0.0  420.000000  15.000000  18.000000
# 1   95.5  257.0     1.0        1.0  121.099476   1.883770   0.538220
# 2   56.0   56.0     0.0        0.0  150.000000   1.000000   9.000000
# 3  198.0  198.0     0.0        0.0  510.000000  29.000000  26.000000
# 4  154.0  117.0     0.0        0.0  379.870130   4.558442  18.993506
#
#    total_carbohydrate     sugars     fiber     calcium       sodium  \
# 0           48.000000  15.000000  2.000000  200.000000  1110.000000
# 1           27.987435  22.605236  0.538220   29.602094     2.691099
# 2           15.000000   0.000000  2.000000    0.000000   310.000000
# 3           40.000000   9.000000  3.000000  300.000000  1190.000000
# 4           47.863636   0.000000  4.558442   15.194805   265.909091
#
#    saturated_fatty_acids  cholesterol
# 0               8.000000        240.0
# 1               0.064586          0.0
# 2               1.500000          0.0
# 3              12.000000         90.0
# 4               2.659091          0.0

# %%
#drop rows with null size/missing values
df_final2 = df_final.dropna(subset=['size'])

# %%
print('About', df_final.shape[0] - df_final2.shape[0], 'number of food uploads are missing from upload information')
# Out:
# About 4359 number of food uploads are missing from upload information

# %%
df_final2.to_csv('Result/Food/food_upload_combined.csv', index=False)

# %% [markdown]
# ## Daily Level Aggregation

# %%
#get day-level date
df_final2 = pd.read_csv('Result/Food/food_upload_combined.csv') 
df_final2['time_upload'] = df_final2['time_upload'].astype('string').str[:10]
df_final2.head(3)
# Out:
#    user_id  Food_ID  Serving_ID1 time_upload serving_time  amount   base  \
# 0        1  1083753        55917  2012-07-18    Breakfast     1.0  164.0
# 1        1  1067522       190733  2012-07-18    Breakfast     1.0   95.5
# 2        1  1055153        19474  2012-07-18    Breakfast     1.0   56.0
#
#     size  credit  fv_credit    calories   protein  total_fat  \
# 0  164.0     0.0        0.0  420.000000  15.00000   18.00000
# 1  257.0     1.0        1.0  121.099476   1.88377    0.53822
# 2   56.0     0.0        0.0  150.000000   1.00000    9.00000
#
#    total_carbohydrate     sugars    fiber     calcium       sodium  \
# 0           48.000000  15.000000  2.00000  200.000000  1110.000000
# 1           27.987435  22.605236  0.53822   29.602094     2.691099
# 2           15.000000   0.000000  2.00000    0.000000   310.000000
#
#    saturated_fatty_acids  cholesterol
# 0               8.000000        240.0
# 1               0.064586          0.0
# 2               1.500000          0.0

# %%
#aggregate day-level nutrients (sum)

df_final3= ps.sqldf("SELECT user_id, time_upload as upload_time, sum(calories) as calories, sum(protein) as protein, sum(total_fat) as total_fat, sum(total_carbohydrate) as total_carbohydrate, sum(sugars) as sugars, sum(fiber) as fiber, sum(calcium) as calciumm, sum(sodium) as sodium, sum(saturated_fatty_acids) as saturated_fatty_acids, sum(cholesterol) as cholesterol, sum(fv_credit) as fv_credit FROM df_final2 group by user_id, time_upload")

# %%
df_final3.head(5)
# Out:
#    user_id upload_time     calories    protein  total_fat  total_carbohydrate  \
# 0        1  2012-07-18   691.099476  17.883770  27.538220           90.987435
# 1        1  2012-07-19  1169.870130  33.558442  44.993506          163.863636
# 2        1  2012-07-20   450.000000  27.500000  37.000000            2.000000
# 3        1  2012-07-25  1602.000000  48.000000  63.000000          249.000000
# 4        1  2012-07-28   915.000000  13.900000  35.000000          123.100000
#
#        sugars     fiber    calciumm       sodium  saturated_fatty_acids  \
# 0   37.605236  4.538220  229.602094  1422.691099               9.564586
# 1    9.000000  7.558442  315.194805  1467.909091              14.659091
# 2    0.000000  0.000000    0.000000     0.000000               0.000000
# 3  121.000000  7.000000    0.000000  2648.000000              25.000000
# 4   72.500000  3.500000   20.000000  1060.052854               5.500000
#
#    cholesterol  fv_credit
# 0        240.0        1.0
# 1         90.0        0.0
# 2          0.0        0.0
# 3        677.0        0.0
# 4          7.5        0.0

# %%
df_final3.to_csv('Result/Food/food_upload_combined_userlevel.csv', index=False)

# %% [markdown]
# ## Statistical Summary

# %% [markdown]
# ### Combine Recipe with Food Items

# %%
df_recipe = pd.read_csv('Result/Food/recipe.csv')
df_food = pd.read_csv('Result/Food/food_upload_combined.csv')
df_food = df_food[pd.to_numeric(df_food['Food_ID'], errors='coerce').notnull()]

# %%
#rename column and select columns of interest
df_recipe.columns = ['user_id',
 'food_id',
 'serving_id',
 'time_upload',
 'name',
 'amount',
 'base',
 'size',
 'creditrecipe',
 'fv_credit',
 'calories',
 'protein',
 'total_fat',
 'total_carbohydrate',
 'sugars',
 'fiber',
 'calcium',
 'sodium',
 'saturated_fatty_acids',
 'cholesterol']

df_food.columns = ['user_id',
 'food_id',
 'serving_id',
 'time_upload',
 'serving_time',
 'amount',
 'base',
 'size',
 'credit',
 'fv_credit',
 'calories',
 'protein',
 'total_fat',
 'total_carbohydrate',
 'sugars',
 'fiber',
 'calcium',
 'sodium',
 'saturated_fatty_acids',
 'cholesterol']

# %%
food_item = df_food_item[['food_id', 'name']]
df_food = pd.merge(food_item , df_food, on=['food_id'])

# %%
columns_interest = ['user_id',
 'food_id',
 'serving_id',
 'time_upload',
 'name',
 'amount',
 'base',
 'size',
 'fv_credit',
 'calories',
 'protein',
 'total_fat',
 'total_carbohydrate',
 'sugars',
 'fiber',
 'calcium',
 'sodium',
 'saturated_fatty_acids',
 'cholesterol']

df_food = df_food[columns_interest]
df_recipe = df_recipe[columns_interest]

# %%
df_food_all = df_food.append(df_recipe)

# %%
df_food_all.head(5)
# Out:
#    user_id  food_id  serving_id          time_upload        name  amount  \
# 0      343  1001004      191059  2013-05-10 13:19:00  Blue, bleu     2.0
# 1      105  1001006      191069  2012-11-10 15:26:16        Brie     0.5
# 2      113  1001006      191070  2012-11-11 23:09:44        Brie     1.5
# 3      200  1001006      191067  2012-12-15 23:04:37        Brie     1.0
# 4      352  1001006      191067  2013-05-20 21:49:14        Brie     1.0
#
#     base   size  fv_credit  calories  protein  total_fat  total_carbohydrate  \
# 0  100.0   17.0        0.0    120.02   7.2760     9.7716              0.7956
# 1  100.0  128.0        0.0    213.76  13.2800    17.7152              0.2880
# 2  100.0  144.0        0.0    721.44  44.8200    59.7888              0.9720
# 3  100.0   17.0        0.0     56.78   3.5275     4.7056              0.0765
# 4  100.0   17.0        0.0     56.78   3.5275     4.7056              0.0765
#
#    sugars  fiber  calcium   sodium  saturated_fatty_acids  cholesterol
# 0  0.1700    0.0   179.52   474.30                6.34746         25.5
# 1  0.2880    0.0   117.76   402.56               11.14240         64.0
# 2  0.9720    0.0   397.44  1358.64               37.60560        216.0
# 3  0.0765    0.0    31.28   106.93                2.95970         17.0
# 4  0.0765    0.0    31.28   106.93                2.95970         17.0

# %%
df_food_all.to_csv('Result/Food/food_all.csv', index=False)

# %%
# aggregate day-level nutrients (sum)
df_food_all_userlevel = ps.sqldf("SELECT user_id, time_upload as upload_time, sum(calories) as calories, sum(protein) as protein, sum(total_fat) as total_fat, sum(total_carbohydrate) as total_carbohydrate, sum(sugars) as sugars, sum(fiber) as fiber, sum(calcium) as calciumm, sum(sodium) as sodium, sum(saturated_fatty_acids) as saturated_fatty_acids, sum(cholesterol) as cholesterol, sum(fv_credit) as fv_credit FROM df_food_all group by user_id, time_upload")

# %%
df_food_all_userlevel.to_csv('Result/Food/food_all_userlevel.csv', index=False)

# %% [markdown]
# ### Tag Variables (by gender, IQR)

# %%
df_food = pd.read_csv('Result/Food/food_all_userlevel.csv')
df_food.head(5)
# Out:
#    user_id          upload_time    calories    protein  total_fat  \
# 0        1  2012-07-18 14:56:44  541.099476  16.883770  18.538220
# 1        1  2012-07-18 15:33:44  150.000000   1.000000   9.000000
# 2        1  2012-07-19 16:43:30  889.870130  33.558442  44.993506
# 3        1  2012-07-19 16:52:49  280.000000   0.000000   0.000000
# 4        1  2012-07-20 09:40:04  450.000000  27.500000  37.000000
#
#    total_carbohydrate     sugars     fiber    calciumm       sodium  \
# 0           75.987435  37.605236  2.538220  229.602094  1112.691099
# 1           15.000000   0.000000  2.000000    0.000000   310.000000
# 2           87.863636   9.000000  7.558442  315.194805  1455.909091
# 3           76.000000   0.000000  0.000000    0.000000    12.000000
# 4            2.000000   0.000000  0.000000    0.000000     0.000000
#
#    saturated_fatty_acids  cholesterol  fv_credit
# 0               8.064586        240.0        1.0
# 1               1.500000          0.0        0.0
# 2              14.659091         90.0        0.0
# 3               0.000000          0.0        0.0
# 4               0.000000          0.0        0.0

# %%
def outliers(df, column, IQR_level):
    l = list(df[column])
    for i in range(0, len(l)): 
        l[i] = float(l[i])
    
    #outlier percentage
    q1 = np.percentile(l, 25)  
    q3 = np.percentile(l, 75)
    IQR = q3-q1
    low = q1 - IQR_level*IQR
    high = q3 + IQR_level*IQR
    
    return([low, high])

# add gender
df_redcap = pd.read_csv('Raw Data/mbc2_redcap.csv') 
df_gender = df_redcap[['Participant ID', 'Sex']]
df_gender.columns = ['study_id', 'gender']
df_user_info = df_user[['study_id','user_id']]
df_info = df_gender.merge(df_user_info, on = 'study_id')
df_info['gender'] = df_info['gender'].astype('string').str[0]

#merge gender with info
df_food_gender = df_food.merge(df_info, on = 'user_id')

#remove user's ID
df_food_gender = df_food_gender.drop(['user_id'], axis=1)
df_food_gender.head(5)
# Out:
#            upload_time    calories    protein  total_fat  total_carbohydrate  \
# 0  2012-07-18 14:56:44  541.099476  16.883770  18.538220           75.987435
# 1  2012-07-18 15:33:44  150.000000   1.000000   9.000000           15.000000
# 2  2012-07-19 16:43:30  889.870130  33.558442  44.993506           87.863636
# 3  2012-07-19 16:52:49  280.000000   0.000000   0.000000           76.000000
# 4  2012-07-20 09:40:04  450.000000  27.500000  37.000000            2.000000
#
#       sugars     fiber    calciumm       sodium  saturated_fatty_acids  \
# 0  37.605236  2.538220  229.602094  1112.691099               8.064586
# 1   0.000000  2.000000    0.000000   310.000000               1.500000
# 2   9.000000  7.558442  315.194805  1455.909091              14.659091
# 3   0.000000  0.000000    0.000000    12.000000               0.000000
# 4   0.000000  0.000000    0.000000     0.000000               0.000000
#
#    cholesterol  fv_credit  study_id gender
# 0        240.0        1.0      1436      1
# 1          0.0        0.0      1436      1
# 2         90.0        0.0      1436      1
# 3          0.0        0.0      1436      1
# 4          0.0        0.0      1436      1

# %%
# split by gender 
df_male = df_food_gender[df_food_gender['gender'] == '1']
df_female = df_food_gender[df_food_gender['gender'] == '2']

#get outliers info
cal_male = outliers(df_male, 'calories', 1.5)
cal_female = outliers(df_female, 'calories', 1.5)
cal_male2 = outliers(df_male, 'calories', 3.0)
cal_female2 = outliers(df_female, 'calories', 3.0)

fv_male = outliers(df_male, 'fv_credit', 1.5)
fv_female = outliers(df_female, 'fv_credit', 1.5)
fv_male2 = outliers(df_male, 'fv_credit', 3.0)
fv_female2 = outliers(df_female, 'fv_credit', 3.0)

fat_male = outliers(df_male, 'total_fat', 1.5)
fat_female = outliers(df_female, 'total_fat', 1.5)
fat_male2 = outliers(df_male, 'total_fat', 3.0)
fat_female2 = outliers(df_female, 'total_fat', 3.0)

# %%
high_male1 = cal_male[1]
high_male2 = cal_male2[1]
high_female1= cal_female[1]
high_female2 = cal_female2[1]

def outliers_cal(row):
    if (row['gender'] == '1'): #male
        if(row['calories'] > high_male2):
            val = 2
        elif(row['calories'] > high_male1):
            val = 1
        else:
            val = 0
    else: #female
        if(row['calories'] > high_female2):
            val = 2
        elif(row['calories'] > high_female1):
            val = 1
        else:
            val = 0
    return val

df_food_gender['calories_outlier'] = df_food_gender.apply(outliers_cal, axis=1)

# %%
high_male1 = fv_male[1]
high_male2 = fv_male2[1]
high_female1= fv_female[1]
high_female2 = fv_female2[1]

def outliers_fv(row):
    if (row['gender'] == '1'): #male
        if(row['fv_credit'] > high_male2):
            val = 2
        elif(row['fv_credit'] > high_male1):
            val = 1
        else:
            val = 0
    else: #female
        if(row['fv_credit'] > high_female2):
            val = 2
        elif(row['fv_credit'] > high_female1):
            val = 1
        else:
            val = 0
    return val

df_food_gender['fv_outlier'] = df_food_gender.apply(outliers_fv, axis=1)

# %%
high_male1 = fat_male[1]
high_male2 = fat_male2[1]
high_female1= fat_female[1]
high_female2 = fat_female2[1]

def outliers_fat(row):
    if (row['gender'] == '1'): #male
        if(row['total_fat'] > high_male2):
            val = 2
        elif(row['total_fat'] > high_male1):
            val = 1
        else:
            val = 0
    else: #female
        if(row['total_fat'] > high_female2):
            val = 2
        elif(row['total_fat'] > high_female1):
            val = 1
        else:
            val = 0
    return val

df_food_gender['fat_outlier'] = df_food_gender.apply(outliers_fat, axis=1)

# %%
df_food_gender.head(5)
# Out:
#            upload_time    calories    protein  total_fat  total_carbohydrate  \
# 0  2012-07-18 14:56:44  541.099476  16.883770  18.538220           75.987435
# 1  2012-07-18 15:33:44  150.000000   1.000000   9.000000           15.000000
# 2  2012-07-19 16:43:30  889.870130  33.558442  44.993506           87.863636
# 3  2012-07-19 16:52:49  280.000000   0.000000   0.000000           76.000000
# 4  2012-07-20 09:40:04  450.000000  27.500000  37.000000            2.000000
#
#       sugars     fiber    calciumm       sodium  saturated_fatty_acids  \
# 0  37.605236  2.538220  229.602094  1112.691099               8.064586
# 1   0.000000  2.000000    0.000000   310.000000               1.500000
# 2   9.000000  7.558442  315.194805  1455.909091              14.659091
# 3   0.000000  0.000000    0.000000    12.000000               0.000000
# 4   0.000000  0.000000    0.000000     0.000000               0.000000
#
#    cholesterol  fv_credit  study_id gender  calories_outlier  fv_outlier  \
# 0        240.0        1.0      1436      1                 0           2
# 1          0.0        0.0      1436      1                 0           0
# 2         90.0        0.0      1436      1                 0           0
# 3          0.0        0.0      1436      1                 0           0
# 4          0.0        0.0      1436      1                 0           0
#
#    fat_outlier
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0

# %%
df_food_gender.to_csv('Result/Food/food_final.csv',  index=False)
